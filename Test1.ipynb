# %%
import os
result = os.system('pip install diagrams')

# %%
from IPython.display import display
from diagrams import Diagram, Node, Cluster, Edge

with Diagram("a", show=False, graph_attr={  }) as diagram:

    with Cluster("a", graph_attr={ "constriant":"False" }) as _pre:
        b = Node("b")
        c = Node("c")

    with Cluster("v", graph_attr={ }) as _mid:
        d = Node("b")
        e = Node("c")

    with Cluster("z", graph_attr={ }) as _post:
        f = Node("b")
        g = Node("c")
        h1 = Node("d")
        j1 = Node("e")

    b >> c
    c >> d
    b >> g

display(diagram.dot)
